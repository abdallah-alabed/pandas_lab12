# %% [markdown]
# # Video Games Stats

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Reading the CSV File

# %%
df = pd.read_csv('archive/vgsales.csv')
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0      2006.0        Sports    Nintendo     41.49     29.02      3.77
# 1      1985.0      Platform    Nintendo     29.08      3.58      6.81
# 2      2008.0        Racing    Nintendo     15.85     12.88      3.79
# 3      2009.0        Sports    Nintendo     15.75     11.01      3.28
# 4      1996.0  Role-Playing    Nintendo     11.27      8.89     10.22
# ...       ...           ...         ...       ...       ...       ...
# 16593  2002.0      Platform       Kemco      0.01      0.00      0.00
# 16594  2003.0       Shooter  Infogrames      0.01      0.00      0.00
# 16595  2008.0        Racing  Activision      0.00      0.00      0.00
# 16596  2010.0        Puzzle    7G//AMES      0.00      0.01      0.00
# 16597  2003.0      Platform     Wanadoo      0.01      0.00      0.00
#
#        Other_Sales  Global_Sales
# 0             8.46         82.74
# 1             0.77         40.24
# 2             3.31         35.82
# 3             2.96         33.00
# 4             1.00         31.37
# ...            ...           ...
# 16593         0.00          0.01
# 16594         0.00          0.01
# 16595         0.00          0.01
# 16596         0.00          0.01
# 16597         0.00          0.01
#
# [16598 rows x 11 columns]

# %% [markdown]
# ## finding most common publisher

# %%
sorted_sales=df.pivot_table(columns=['Publisher'], aggfunc='size')
sorted_sales=sorted_sales.sort_values(ascending=False)
sorted_sales.head(1)
# Out:
# Publisher
# Electronic Arts    1351
# dtype: int64

# %% [markdown]
# ## finding most common platform + its count

# %%
platforms=df['Platform'].value_counts()
platforms.head(1)
# Out:
# DS    2163
# Name: Platform, dtype: int64

# %% [markdown]
# ## finding most common genre

# %%
genre=df['Genre'].value_counts()
genre.head(1)
# Out:
# Action    3316
# Name: Genre, dtype: int64

# %% [markdown]
# ## finding top 20 highest grossing games

# %%
top_20=df[['Name' , 'Global_Sales']]
top_20.head(20)
# Out:
#                                             Name  Global_Sales
# 0                                     Wii Sports         82.74
# 1                              Super Mario Bros.         40.24
# 2                                 Mario Kart Wii         35.82
# 3                              Wii Sports Resort         33.00
# 4                       Pokemon Red/Pokemon Blue         31.37
# 5                                         Tetris         30.26
# 6                          New Super Mario Bros.         30.01
# 7                                       Wii Play         29.02
# 8                      New Super Mario Bros. Wii         28.62
# 9                                      Duck Hunt         28.31
# 10                                    Nintendogs         24.76
# 11                                 Mario Kart DS         23.42
# 12                   Pokemon Gold/Pokemon Silver         23.10
# 13                                       Wii Fit         22.72
# 14                                  Wii Fit Plus         22.00
# 15                            Kinect Adventures!         21.82
# 16                            Grand Theft Auto V         21.40
# 17                 Grand Theft Auto: San Andreas         20.81
# 18                             Super Mario World         20.61
# 19  Brain Age: Train Your Brain in Minutes a Day         20.22

# %% [markdown]
# ## NA Games Median

# %%
north_amc_med=df['NA_Sales'].median()
north_amc_med
# Out:
# 0.08

# %% [markdown]
# ## For the top-selling game of all time, how many standard deviations above/below the mean are its sales for North America?

# %%
north_amc_std=(df['NA_Sales'].head(1)-df['NA_Sales'].mean())/df['NA_Sales'].std()
north_amc_std
# Out:
# 0    50.478988
# Name: NA_Sales, dtype: float64

# %% [markdown]
# ## The Nintendo Wii seems to have outdone itself with games. How does its average number of sales compare with all of the other platforms?

# %%
wii = df[df['Platform'] == 'Wii']
wii_sales = wii.Global_Sales
avg = wii_sales.mean()
print('Wii mean', avg)

others = df[df['Platform'] != 'Wii']
not_Wii = others.Global_Sales
avg_not_wii = not_Wii.mean()
print('Not Wii mean', avg_not_wii)
# Out:
# Wii mean 0.6994037735849057
# Not Wii mean 0.5233896418516336

# %% [markdown]
# ## extra three questions
# 1. filter games that was published before the year 2000
# 2. top 10 game sales in Japan
# 3. highest 5 racing games global sales

# %%
filter_data=df[ df['Year'] < 2000 ]
filter_data.sort_values('Year')
# Out:
#         Rank                                           Name Platform    Year  \
# 6317    6319                                         Bridge     2600  1980.0
# 6896    6898                                       Checkers     2600  1980.0
# 1969    1971                                       Defender     2600  1980.0
# 1766    1768                                        Kaboom!     2600  1980.0
# 5366    5368                                        Freeway     2600  1980.0
# ...      ...                                            ...      ...     ...
# 8099    8101                                        Re-Volt      N64  1999.0
# 8098    8100         Sesame Street: Elmo's Letter Adventure      N64  1999.0
# 1856    1858  Yu-Gi-Oh! Duel Monsters II: Dark Duel Stories       GB  1999.0
# 8582    8584                             Asteroids Hyper 64      N64  1999.0
# 16583  16586                                 Carmageddon 64      N64  1999.0
#
#           Genre                     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 6317       Misc                    Activision      0.25      0.02       0.0
# 6896       Misc                         Atari      0.22      0.01       0.0
# 1969       Misc                         Atari      0.99      0.05       0.0
# 1766       Misc                    Activision      1.07      0.07       0.0
# 5366     Action                    Activision      0.32      0.02       0.0
# ...         ...                           ...       ...       ...       ...
# 8099     Racing         Acclaim Entertainment      0.14      0.04       0.0
# 8098       Misc                      NewKidCo      0.14      0.04       0.0
# 1856   Strategy  Konami Digital Entertainment      0.00      0.00       1.1
# 8582    Shooter           Crave Entertainment      0.13      0.03       0.0
# 16583    Action            Virgin Interactive      0.01      0.00       0.0
#
#        Other_Sales  Global_Sales
# 6317          0.00          0.27
# 6896          0.00          0.24
# 1969          0.01          1.05
# 1766          0.01          1.15
# 5366          0.00          0.34
# ...            ...           ...
# 8099          0.00          0.18
# 8098          0.00          0.18
# 1856          0.00          1.10
# 8582          0.00          0.16
# 16583         0.00          0.01
#
# [1974 rows x 11 columns]

# %%
japan_data=df[['Name' ,'JP_Sales']]
japan_data.sort_values('JP_Sales',ascending=False).head(10)
# Out:
#                                             Name  JP_Sales
# 4                       Pokemon Red/Pokemon Blue     10.22
# 12                   Pokemon Gold/Pokemon Silver      7.20
# 1                              Super Mario Bros.      6.81
# 6                          New Super Mario Bros.      6.50
# 20                 Pokemon Diamond/Pokemon Pearl      6.04
# 26                   Pokemon Black/Pokemon White      5.65
# 25                 Pokemon Ruby/Pokemon Sapphire      5.38
# 41                   Animal Crossing: Wild World      5.33
# 27   Brain Age 2: More Training in Minutes a Day      5.32
# 214                     Monster Hunter Freedom 3      4.87

# %%
racing=df[ df['Genre'] == 'Racing']
racing=racing[['Name' ,'Platform' ,'Global_Sales']]
racing.head(5)
# Out:
#                       Name Platform  Global_Sales
# 2           Mario Kart Wii      Wii         35.82
# 11           Mario Kart DS       DS         23.42
# 28  Gran Turismo 3: A-Spec      PS2         14.98
# 42            Mario Kart 7      3DS         12.21
# 47          Gran Turismo 4      PS2         11.66
